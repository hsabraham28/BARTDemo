# %%
import pandas as pd
import numpy as np
from IPython import display
from matplotlib import image
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import ipywidgets as widgets
# %matplotlib notebook
from ipywidgets import *
import matplotlib.pyplot as pltp
# %matplotlib inline

# %%
stationlocs = pd.read_csv("assets/BARTLocationPercentages.csv")
stationlocs.head(5)
# Out:
#   Station_Name  X_Percentage  Y_Percentage  Rain_Critical  \
# 0  A50_TCR_105        51.968        57.745              1
# 1      A10_TCR        41.631        46.257              1
# 2      R60_TCR        24.080        13.060              1
# 3  R50_TCR_105        26.500        15.830              1
# 4      R10_TCR        36.250        26.480              1
#
#          Asset_Location
# 0              Bay Fair
# 1          Lake Merritt
# 2              Richmond
# 3  El Cerrito Del Norte
# 4                 Ashby

# %%
vizpic = display.Image("assets/BARTtracksmap.png")
picdata = image.imread('assets/BARTtracksmap.png')

# %%
testlog = pd.read_csv("occ-log-classification/csv/labeled.csv").head(60)

print(testlog.columns)
testlog.head(10)
# Out:
# Index(['Time', 'Log', 'Cat'], dtype='object')
#     Time                                                Log  Cat
# 0    2.0                     T385 released, 5 minutes late.   10
# 1  400.0  CAR COUNT\nA’s:  51   B’s:   329   C’s:   172 ...   10
# 2  400.0  Daily SCRAM / Spare Train Report: OCY: T337 Ho...   10
# 3  443.0  T229 late dispatching OHY due to FW scheduling...    7
# 4  447.0  T229 verifies A78 [A1 & A2 tracks] cranked, cl...    6
# 5  500.0  BPD performing QOL sweeps T373, T513, T375, T5...    1
# 6  514.0  T361 verifies C35 A-B cranks, clamps & bolts i...    6
# 7  555.0  T373 verifies C35 C-D cranked, clamped, bolted...    6
# 8  631.0         Charlie53 [Schexnayder] @ M10 for commute.   10
# 9  635.0                   M45 [Johnson] @ M16 for commute.   10

# %%
station_list = (stationlocs['Station_Name']).tolist()
s_abbrv = [station[:3] for station in station_list]

# %%
def lookfornames(c):
    for s in s_abbrv:
        if s in c:
            return s
        
stationlocs['Location'] = testlog["Log"].apply(lookfornames)
testlog['Location'] = testlog["Log"].apply(lookfornames)

# %%
stationlocs.head(10)
# Out:
#    Station_Name  X_Percentage  Y_Percentage  Rain_Critical  \
# 0   A50_TCR_105        51.968        57.745              1
# 1       A10_TCR        41.631        46.257              1
# 2       R60_TCR        24.080        13.060              1
# 3   R50_TCR_105        26.500        15.830              1
# 4       R10_TCR        36.250        26.480              1
# 5  M90_TCR_116A        20.136        68.617              1
# 6   M90_TCR_114        20.158        68.638              1
# 7   M90_TCR_113        20.133        68.611              1
# 8   M90_TCR_112        20.127        68.598              1
# 9       M10_TCR        35.195        42.561              1
#
#          Asset_Location Location
# 0              Bay Fair     None
# 1          Lake Merritt     None
# 2              Richmond      L30
# 3  El Cerrito Del Norte      OHY
# 4                 Ashby     None
# 5             Daly City      M16
# 6             Daly City      C30
# 7             Daly City      C40
# 8             Daly City      M10
# 9          West Oakland      M16

# %%
justxandy = stationlocs.drop(columns=['Station_Name', 'Rain_Critical', 'Asset_Location'])
justxandy.head(5)
# Out:
#    X_Percentage  Y_Percentage Location
# 0        51.968        57.745     None
# 1        41.631        46.257     None
# 2        24.080        13.060      L30
# 3        26.500        15.830      OHY
# 4        36.250        26.480     None

# %%
merged = testlog.merge(justxandy.set_index('Location'), on='Location')
merged.head(5)
# Out:
#    Time                             Log  Cat Location  X_Percentage  \
# 0   2.0  T385 released, 5 minutes late.   10     None        51.968
# 1   2.0  T385 released, 5 minutes late.   10     None        41.631
# 2   2.0  T385 released, 5 minutes late.   10     None        36.250
# 3   2.0  T385 released, 5 minutes late.   10     None        34.330
# 4   2.0  T385 released, 5 minutes late.   10     None        34.330
#
#    Y_Percentage
# 0        57.745
# 1        46.257
# 2        26.480
# 3        77.576
# 4        77.590

# %%
merged['dupped'] = merged.duplicated(subset=['Log'])
merged = merged[merged.dupped != True]

# %%
vizdata = merged.drop(columns=['dupped'])

# %%
from tensorflow import keras
model = keras.models.load_model('occ-log-classification/model')

# %%
class_legend = MLB_team = {
    0:"Misc",
    1:'Other BPD',
    2:'Homeless',
    3:'Medical',
    4:'Patron interference',
    5:"Vehicle failure",
    6:"Wayside equipment",
    7:"Software related failures",
    8:"Human Error",
    9:"Weather",
    10:"Info (no error)",
    11:"Delays",
    12:"Track obstruction",
    13:"Schedule maintenance"
}

# %%
vizdata['Cat_Pred'] = vizdata['Log'].apply(lambda log: np.argmax(model.predict([log]), axis=1)[0])

# %%
vizdata['Class_Pred'] = vizdata['Cat_Pred'].apply(lambda code: class_legend[code])

# %%
vizdata.head(10)
# Out:
#         Time                                                Log  Cat Location  \
# 0        2.0                     T385 released, 5 minutes late.   10     None
# 250    400.0  CAR COUNT\nA’s:  51   B’s:   329   C’s:   172 ...   10     None
# 500    447.0  T229 verifies A78 [A1 & A2 tracks] cranked, cl...    6     None
# 750    720.0                                 T507 released ATO.   10     None
# 1000   814.0  [MDRX] T381 reporting medical emergency on C18...    3     None
# 1250   858.0             T371 released ATO, (118) seconds late.   11     None
# 1500   931.0  T113 stopped with zero speed A57 gate Echo, is...    6     None
# 1750  1005.0                                 T105 released ATO.   10     None
# 2000  1045.0  Grounds Superintendent reports hole in fence M...    6     None
# 2250  1202.0             T451 released ATO, (105) second delay.   11     None
#
#       X_Percentage  Y_Percentage  Cat_Pred         Class_Pred
# 0           51.968        57.745        10    Info (no error)
# 250         51.968        57.745        10    Info (no error)
# 500         51.968        57.745         6  Wayside equipment
# 750         51.968        57.745        10    Info (no error)
# 1000        51.968        57.745         3            Medical
# 1250        51.968        57.745        11             Delays
# 1500        51.968        57.745         0               Misc
# 1750        51.968        57.745        10    Info (no error)
# 2000        51.968        57.745         8        Human Error
# 2250        51.968        57.745        11             Delays

# %%
def update(time = 622):
  
    fig = plt.figure(figsize=(10, 8), dpi=200)
    plt.imshow(picdata)
    for index,row in vizdata.iterrows():
        if row['Time'] <= time:
            plt.plot(1200* (row['X_Percentage']/100), 1100 * (row['Y_Percentage']/100), marker='v', color="blue")

    fig.canvas.draw_idle()

interact(update, time = widgets.IntSlider(value=622, min=500, max=1200, step=1));
# Out:
# interactive(children=(IntSlider(value=622, description='time', max=1200, min=500), Output()), _dom_classes=('w…

# %%
maptable = vizdata
maptable["xplot"] = (1200* (maptable['X_Percentage']/100))
maptable["yplot"] = (1080* (maptable['Y_Percentage']/100))
maptable
frametable = maptable[["xplot", "yplot"]]
xvals = maptable['xplot']
yvals = maptable['yplot']
maptable.head(5)
# Out:
#        Time                                                Log  Cat Location  \
# 0       2.0                     T385 released, 5 minutes late.   10     None
# 250   400.0  CAR COUNT\nA’s:  51   B’s:   329   C’s:   172 ...   10     None
# 500   447.0  T229 verifies A78 [A1 & A2 tracks] cranked, cl...    6     None
# 750   720.0                                 T507 released ATO.   10     None
# 1000  814.0  [MDRX] T381 reporting medical emergency on C18...    3     None
#
#       X_Percentage  Y_Percentage  Pred_Cat         Pred_Class    xplot  \
# 0           51.968        57.745         5    Vehicle failure  623.616
# 250         51.968        57.745        10    Info (no error)  623.616
# 500         51.968        57.745         6  Wayside equipment  623.616
# 750         51.968        57.745         5    Vehicle failure  623.616
# 1000        51.968        57.745         3            Medical  623.616
#
#         yplot
# 0     623.646
# 250   623.646
# 500   623.646
# 750   623.646
# 1000  623.646

# %%
#plotly conversion hopefully
import plotly.graph_objects as go
import base64
import plotly.express as px
# Create figure
mapfig = go.Figure()



img_width = 1200
img_height = 1080
mapfig.update_layout(
    autosize=False
   

)


bartimage = base64.b64encode(open("assets/BARTtracksmap.png", 'rb').read())
mapfig.add_layout_image(
        dict(
            source='data:image/png;base64,{}'.format(bartimage.decode()), #"./assets/BARTtracksmap.png",
            xref="x",
            yref="y",
            x=0,
            y=0,
            sizex=img_width,
            sizey=img_height,
            #sizing="stretch",
            opacity=1,
            sizing='contain',
            layer="below",xanchor="left", yanchor="top")
)
mapfig.update_xaxes(showgrid=False, range=(0, img_width))
mapfig.update_yaxes(showgrid=False, scaleanchor='x', range=(img_height, 0))

mapfig.add_trace(
    go.Scatter(x=maptable["xplot"], y=maptable["yplot"], mode="markers", text=maptable['Log'])
    
)





mapfig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-163e8ce34bc5> in <module>
#      17
#      18
# ---> 19 bartimage = base64.b64encode(open("./BARTtracksmap.png", 'rb').read())
#      20 mapfig.add_layout_image(
#      21         dict(
#
# FileNotFoundError: [Errno 2] No such file or directory: './BARTtracksmap.png'

# %%
catvizdata = vizdata.drop(columns=['X_Percentage', 'Y_Percentage'])
cattypes = ['Police Activity',
'Unhoused',
'medical emergencies',
'patron interference',
'vehicle failures',
'wayside equipment',
'miscellaneous',
'software related failures',
'human error',
'weather']
categories = []
for i in catvizdata['Location']:
    categories = np.append(categories, np.random.choice(cattypes))
catvizdata['Category'] = categories
refs = []
refs = np.random.choice(np.arange(len(catvizdata['Location'])), len(catvizdata['Location']), replace=False)

catvizdata['Reference'] = refs
catvizdata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-435a9079eeef> in <module>
# ----> 1 catvizdata = vizdata.drop(columns=['X_Percentage', 'Y_Percentage'])
#       2 cattypes = ['Police Activity',
#       3 'Unhoused',
#       4 'medical emergencies',
#       5 'patron interference',
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: "['X_Percentage' 'Y_Percentage'] not found in axis"

# %%
import datetime
timarr = []
for t in catvizdata['Time']:
    t = int(t)
    temp = datetime.time(t//100, t%100)
    timarr.append(temp)
catvizdata['Time'] = timarr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-273ba32f59b5> in <module>
#       1 import datetime
#       2 timarr = []
# ----> 3 for t in catvizdata['Time']:
#       4     t = int(t)
#       5     temp = datetime.time(t//100, t%100)
#
# NameError: name 'catvizdata' is not defined

# %%
from datetime import time
timeaxis = []
start = datetime.time(5, 0, 0)
end = datetime.time(22, 0, 0)
currhr = 5
currmin = 1
timeaxis.append(start)
for i in range(1020):
    nexttime = datetime.time(currhr, currmin, 0)
    timeaxis.append(nexttime)
    if currmin == 59:
        currmin = 0
        currhr = currhr + 1
    else:
        currmin = currmin + 1
catvizdata = catvizdata.sort_values(by=['Time'])
xaxistime = catvizdata['Time']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-ce7c9603d851> in <module>
#      14     else:
#      15         currmin = currmin + 1
# ---> 16 catvizdata = catvizdata.sort_values(by=['Time'])
#      17 xaxistime = catvizdata['Time']
#
# NameError: name 'catvizdata' is not defined

# %%
import plotly.express as px
swimscatter = px.scatter(catvizdata, y="Class", x='Time', color="Class", symbol="Class", hover_data=['Log', 'Location'])
swimscatter.update_traces(marker_size=20)
swimscatter.update_xaxes(categoryorder='category ascending', showgrid=False)
swimscatter.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-58c69e44b156> in <module>
#       1 import plotly.express as px
# ----> 2 swimscatter = px.scatter(catvizdata, y="Class", x='Time', color="Class", symbol="Class", hover_data=['Log', 'Location'])
#       3 swimscatter.update_traces(marker_size=20)
#       4 swimscatter.update_xaxes(categoryorder='category ascending', showgrid=False)
#       5 swimscatter.show()
#
# NameError: name 'catvizdata' is not defined

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=mapfig),
    dcc.Graph(figure=swimscatter)
], 
)

app.run_server(debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-779bbed18c7b> in <module>
# ----> 1 import dash
#       2 import dash_core_components as dcc
#       3 import dash_html_components as html
#       4
#       5 app = dash.Dash()
#
# ModuleNotFoundError: No module named 'dash'
